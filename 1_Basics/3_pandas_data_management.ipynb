# %%
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot

Dataset = load_dataset ('lukebarousse/data_jobs')
df= Dataset['train'].to_pandas()

df ['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df.head()
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2               Berlin, Germany        via LinkedIn         Full-time
# 3               San Antonio, TX   via Diversity.com         Full-time
# 4                Washington, DC  via Clearance Jobs         Full-time
#
#    job_work_from_home       search_location     job_posted_date  \
# ...

# %%
df.sample(10)
# Out:
#               job_title_short  \
# 471704           Data Analyst
# 430197         Data Scientist
# 212629         Data Scientist
# 113789         Cloud Engineer
# 43986   Senior Data Scientist
# 200076         Cloud Engineer
# 616293          Data Engineer
# 769142           Data Analyst
# 490532  Senior Data Scientist
# 8080            Data Engineer
#
#                                               job_title  \
# 471704                           Data Analyst, Payments
# 430197                         Principal Data Scientist
# 212629                        Biomedical Data Scientist
# 113789                         Hosting Services Analyst
# 43986   Senior Data Scientist, Experimentation Platform
# 200076                      Cohesity Technical Engineer
# 616293                         Data Engineer Internship
# 769142                 Senior Research and Data Analyst
# 490532                      福岡 Project Leader- データエンジニア
# 8080                            Principal Data Engineer
#
# ...

# %%
df_test=df.copy
monthly_salary = df.salary_year_avg.median()
df_test['salary_year_avg'] = df_test['salary_year_avg'].fillna(monthly_salary)

# %%
df_test['salary_year_avg']
# Out:
# 0         115000.0
# 1         115000.0
# 2         115000.0
# 3         115000.0
# 4         115000.0
#             ...
# 785736    115000.0
# 785737    115000.0
# 785738    115000.0
# 785739    115000.0
# 785740    115000.0
# Name: salary_year_avg, Length: 785741, dtype: float64

# %%
df['salary_year_avg']
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#           ..
# 785736   NaN
# 785737   NaN
# 785738   NaN
# 785739   NaN
# 785740   NaN
# Name: salary_year_avg, Length: 785741, dtype: float64

# %%
df_test=df
monthly_salary = df.salary_year_avg.median()
df_test['salary_year_avg'] = df_test['salary_year_avg'].fillna(monthly_salary)

# %%
df_test['salary_year_avg']
# Out:
# 0         115000.0
# 1         115000.0
# 2         115000.0
# 3         115000.0
# 4         115000.0
#             ...
# 785736    115000.0
# 785737    115000.0
# 785738    115000.0
# 785739    115000.0
# 785740    115000.0
# Name: salary_year_avg, Length: 785741, dtype: float64

# %%
df['salary_year_avg']
# Out:
# 0         115000.0
# 1         115000.0
# 2         115000.0
# 3         115000.0
# 4         115000.0
#             ...
# 785736    115000.0
# 785737    115000.0
# 785738    115000.0
# 785739    115000.0
# 785740    115000.0
# Name: salary_year_avg, Length: 785741, dtype: float64
