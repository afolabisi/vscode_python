# %%
import numpy as np
import ast
import pandas as pd
import matplotlib.pyplot as plt
from datasets import load_dataset

dataset = load_dataset('lukebarousse/data_jobs')
df= dataset['train'].to_pandas()

df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df['job_skills'] = df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.

# %%
df.job_work_from_home.value_counts().plot(kind='pie', startangle=90, autopct='%1.1f%%')
plt.title('Work from Home Status')
plt.show()

# %%
df.job_title_short.value_counts().plot(kind='pie')
plt.title('Job_Title')
plt.show()

# %%
df.job_title_short.value_counts(ascending=True).plot(kind='barh')
plt.title('Job_Title')
plt.show()

# %%
fig, ax=plt.subplots(1, 3)

dict_columns= {
    'job_work_from_home': 'Work from Home Status',
    'job_no_degree_mention': 'No Degree Required',
    'job_health_insurance': 'Health Issurance Offered'
}
for i, (column, title) in enumerate(dict_columns.items()):
    print(i, column, title)
    ax[i].pie(df[column].value_counts(), startangle=90, autopct='%1.1f%%', labels=['False','True'])
    ax[i].set_title(title)

fig.tight_layout()
# Out:
# 0 job_work_from_home Work from Home Status
# 1 job_no_degree_mention No Degree Required
# 2 job_health_insurance Health Issurance Offered
